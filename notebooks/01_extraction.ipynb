# %% [markdown]
# # Amazon Product Sales Data Analysis

# %% [markdown]
# This notebook performs an initial analysis of Amazon product sales data.

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/Aman739-code/E_G1_DVACapstone2/master/data/raw/amazon_products_sales_data_uncleaned.csv")

# %% [markdown]
# Loading the raw Amazon product sales data from a CSV file into a pandas DataFrame.

# %% [markdown]
# ## Data Loading

# %%
df.head()
# Out:
#                                                title              rating  \
# 0  BOYA BOYALINK 2 Wireless Lavalier Microphone f...  4.6 out of 5 stars
# 1  LISEN USB C to Lightning Cable, 240W 4 in 1 Ch...  4.3 out of 5 stars
# 2  DJI Mic 2 (2 TX + 1 RX + Charging Case), Wirel...  4.6 out of 5 stars
# 3  Apple AirPods Pro 2 Wireless Earbuds, Active N...  4.6 out of 5 stars
# 4  Apple AirTag 4 Pack. Keep Track of and find Yo...  4.8 out of 5 stars
#
#   number_of_reviews       bought_in_last_month current/discounted_price  \
# 0               375  300+ bought in past month                    89.68
# 1             2,457   6K+ bought in past month                     9.99
# 2             3,044   2K+ bought in past month                   314.00
# 3            35,882  10K+ bought in past month                      NaN
# 4            28,988  10K+ bought in past month                      NaN
#
#                price_on_variant listed_price is_best_seller is_sponsored  \
# ...

# %% [markdown]
# Displaying the first 5 rows of the DataFrame to get a preliminary look at the data structure and content.

# %% [markdown]
# ## Initial Data Exploration

# %%
df.shape
# Out:
# (42675, 16)

# %% [markdown]
# Checking the shape of the DataFrame to see the total number of rows and columns.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42675 entries, 0 to 42674
# Data columns (total 16 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   title                     42675 non-null  object
#  1   rating                    41651 non-null  object
#  2   number_of_reviews         41651 non-null  object
#  3   bought_in_last_month      39458 non-null  object
#  4   current/discounted_price  30926 non-null  object
#  5   price_on_variant          42675 non-null  object
#  6   listed_price              42675 non-null  object
#  7   is_best_seller            42675 non-null  object
#  8   is_sponsored              42675 non-null  object
#  9   is_couponed               42675 non-null  object
#  10  buy_box_availability      28022 non-null  object
#  11  delivery_details          30955 non-null  object
#  12  sustainability_badges     3408 non-null   object
# ...

# %% [markdown]
# Getting a concise summary of the DataFrame, including data types, non-null values, and memory usage. This helps identify columns with missing data and incorrect data types.

# %%
df.describe()
# Out:
#                                                     title              rating  \
# count                                               42675               41651
# unique                                               8808                  31
# top     Duracell Coppertop 9V Battery, 6 Count (Pack o...  4.6 out of 5 stars
# freq                                                  744                6151
#
#        number_of_reviews       bought_in_last_month current/discounted_price  \
# count              41651                      39458                    30926
# unique              4413                         59                     2576
# top                   25  100+ bought in past month                    29.99
# freq                 626                       8801                      825
#
#                 price_on_variant listed_price is_best_seller is_sponsored  \
# count                      42675        42675          42675        42675
# ...

# %% [markdown]
# Generating descriptive statistics for the DataFrame. For numerical columns, this includes count, mean, std, min, max, and quartiles. For object (string) columns, it shows count, unique, top, and freq.

# %%
df.isnull().sum()
# Out:
# title                           0
# rating                       1024
# number_of_reviews            1024
# bought_in_last_month         3217
# current/discounted_price    11749
# price_on_variant                0
# listed_price                    0
# is_best_seller                  0
# is_sponsored                    0
# is_couponed                     0
# buy_box_availability        14653
# delivery_details            11720
# sustainability_badges       39267
# image_url                       0
# product_url                  2069
# collected_at                    0
# dtype: int64

# %% [markdown]
# Calculating the number of missing (null) values for each column in the DataFrame. This is crucial for understanding data completeness and planning missing value imputation strategies.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# Checking for duplicate rows in the DataFrame. Identifying and handling duplicates is important for data integrity and to avoid bias in analysis.
